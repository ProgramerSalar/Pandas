# %%
import pandas as pd 
import numpy as np

# %%
movie_data = pd.read_csv('C:\\Users\\Mandhata Kumar\\Machine_Learning\\Pandas\\DataFrame\\imdb-top-1000.csv')
movie_data
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 974    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 975                     Giant          1956      201   Drama          7.6
# 976     From Here to Eternity          1953      118   Drama          7.6
# 977                  Lifeboat          1944       97   Drama          7.6
# 978              The 39 Steps          1935       86   Crime          7.6
#
#                  Director              Star1  No_of_Votes        Gross  \
# ...

# %%
genres = movie_data.groupby('Genre')

# %%
# find the top 3 generes by total earning 
generes = movie_data.groupby('Genre')['Gross'].sum().sort_values(ascending=False).head(3)
generes
# Out:
# Genre
# Drama     3.503815e+10
# Action    3.174757e+10
# Comedy    1.560627e+10
# Name: Gross, dtype: float64
