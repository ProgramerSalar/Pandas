# %% [markdown]
# # Types of Data
# * Numerical Data
# * Categorical Data

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ### 2D Line plot
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Bivariate Analysis
# * categorical
# * numerical
# * Use case -> Time series data

# %%
# plotting a simple function 
price = [48000,54000,57000,49000,47000,45000]
year = [2015,2016,2017,2018,2019,2020]

plt.plot(year, price)

# %%
# from a pandas dataframe 
batsman = pd.read_csv('C:\\Users\\Mandhata Kumar\\Machine_Learning\\Pandas\\Data\\sharma-kohli.csv')
batsman

plt.plot(batsman['index'], batsman['V Kohli'])
plt.title('runs vs year')
# Out:
# Text(0.5, 1.0, 'runs vs year')

# %%
# plotting multiple plots 
plt.plot(batsman['index'], batsman['V Kohli'])
plt.plot(batsman['index'], batsman['RG Sharma'])

# %%
# label title 
plt.plot(batsman['index'], batsman['V Kohli'])
plt.plot(batsman['index'], batsman['RG Sharma'])

plt.title('Rohit Sharma Vs Virat Kohli Carrer Comparison')
plt.xlabel('Season')
plt.ylabel('Runs Scord')
# Out:
# Text(0, 0.5, 'Runs Scord')

# %%
# change the color 
# label title 
plt.plot(batsman['index'], batsman['V Kohli'], color="red")
plt.plot(batsman['index'], batsman['RG Sharma'], color='pink')

plt.title('Rohit Sharma Vs Virat Kohli Carrer Comparison')
plt.xlabel('Season')
plt.ylabel('Runs Scord')
# Out:
# Text(0, 0.5, 'Runs Scord')
